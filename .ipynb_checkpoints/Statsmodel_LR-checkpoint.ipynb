# %% [markdown]
# ## 로지스틱 회귀 적용 (statsmodels)
#
# * Logit

# %%
import pandas as pd
import numpy as np
import os, sys, time
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression
import statsmodels.api as sm
from sklearn.model_selection import train_test_split

from sklearn.metrics import accuracy_score  
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import roc_auc_score
from sklearn.metrics import classification_report

# %% [markdown]
# ### 데이터세트 로딩

# %%
FILENAME = 'FZ_Data/FZ_all_ffill.csv'

if not os.path.exists(FILENAME):
    assert False, 'cannot find FILENAME: {}'.format(FILENAME)
else:
    print('found : {}'.format(FILENAME))
# Out:
# found : FZ_Data/FZ_all_ffill.csv

# %%
if FILENAME.endswith('.xlsx'):
    df = pd.read_excel(FILENAME, 
                       header=0,
                       encoding='euc-kr',
                       converters={'지점':str, '지면상태(지면상태코드)':str, '현상번호(국내식)':str})
elif FILENAME.endswith('.csv'):
    df = pd.read_csv(FILENAME, 
                     header=0,
                     encoding='euc-kr',
                     converters={'지점':str, '지면상태(지면상태코드)':str, '현상번호(국내식)':str})

# %%
df.columns
# Out:
# Index(['지점', '지점명', '일시', '기온(°C)', '강수량(mm)', '풍속(m/s)', '풍향(16방위)', '습도(%)',
#        '증기압(hPa)', '이슬점온도(°C)', '현지기압(hPa)', '해면기압(hPa)', '일조(hr)',
#        '일사(MJ/m2)', '적설(cm)', '3시간신적설(cm)', '전운량(10분위)', '중하층운량(10분위)',
#        '운형(운형약어)', '최저운고(100m )', '시정(10m)', '지면상태(지면상태코드)', '현상번호(국내식)',
#        '지면온도(°C)', 'FZ_flag'],
#       dtype='object')

# %%
use_colmns = ['지점', '지점명', '일시', '기온(°C)', '강수량(mm)', 
       '풍속(m/s)', '풍향(16방위)', '습도(%)', 
       '증기압(hPa)', '이슬점온도(°C)', '현지기압(hPa)', '해면기압(hPa)',
       '일조(hr)', '일사(MJ/m2)', '적설(cm)', '3시간신적설(cm)',
       '전운량(10분위)', '중하층운량(10분위)', '운형(운형약어)', '최저운고(100m )', '시정(10m)',
       '지면상태(지면상태코드)', '현상번호(국내식)', '지면온도(°C)',
       'FZ_flag']

df = df[use_colmns]

# %%
df.shape
# Out:
# (29015, 25)

# %% [markdown]
# ## 한글 컬럼이름들을 영문으로 변경함

# %%
df.rename(columns = {'지점' : 'Office',
                      '지점명' : 'Office_Name',
                      '일시' : 'Date',
                      '기온(°C)': 'Temp', 
                      '강수량(mm)': 'Rain', 
                      '풍속(m/s)': 'WindSpeed', 
                      '풍향(16방위)': 'WindDir',  
                      '습도(%)': 'Moist',
                      '증기압(hPa)': 'hPa', 
                      '이슬점온도(°C)': 'DewTemp', 
                      '현지기압(hPa)': 'CurhPa', 
                      '해면기압(hPa)': 'SeahPa',
                      '일조(hr)': 'Daylight', 
                      '일사(MJ/m2)': 'DaylightMJ', 
                      '적설(cm)': 'SnowCm', 
                      '3시간신적설(cm)': 'Snow3hr',
                      '전운량(10분위)': 'Clouds_10', 
                      '중하층운량(10분위)': 'MClouds_10',                      
                      '운형(운형약어)' : 'CloudDesigns_Abb',                     
                      '최저운고(100m )': 'HClouds_100m', 
                      '시정(10m)': 'Visibility_10m', 
                      '지면상태(지면상태코드)': 'GroundState_Code',
                      '현상번호(국내식)': 'PhenomenaNo',
                      '지면온도(°C)': 'SurfaceTemp'
                     }, inplace=True)

# %%
df.columns
# Out:
# Index(['Office', 'Office_Name', 'Date', 'Temp', 'Rain', 'WindSpeed', 'WindDir',
#        'Moist', 'hPa', 'DewTemp', 'CurhPa', 'SeahPa', 'Daylight', 'DaylightMJ',
#        'SnowCm', 'Snow3hr', 'Clouds_10', 'MClouds_10', 'CloudDesigns_Abb',
#        'HClouds_100m', 'Visibility_10m', 'GroundState_Code', 'PhenomenaNo',
#        'SurfaceTemp', 'FZ_flag'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Office               object
# Office_Name          object
# Date                 object
# Temp                float64
# Rain                float64
# WindSpeed           float64
# WindDir               int64
# Moist               float64
# hPa                 float64
# DewTemp             float64
# CurhPa              float64
# SeahPa              float64
# Daylight            float64
# DaylightMJ          float64
# SnowCm              float64
# Snow3hr             float64
# Clouds_10           float64
# MClouds_10          float64
# CloudDesigns_Abb     object
# HClouds_100m        float64
# Visibility_10m      float64
# GroundState_Code     object
# PhenomenaNo          object
# SurfaceTemp         float64
# FZ_flag               int64
# dtype: object

# %%
df.groupby(['FZ_flag']).size()
# Out:
# FZ_flag
# 0    28946
# 1       69
# dtype: int64

# %% [markdown]
# ### Pandas correlation matrix

# %%
df.corr()
# Out:
#                     Temp      Rain  WindSpeed   WindDir     Moist       hPa  \
# Temp            1.000000  0.036713   0.024753 -0.024835 -0.197061  0.701251
# Rain            0.036713  1.000000  -0.006566 -0.038189  0.131087  0.129700
# WindSpeed       0.024753 -0.006566   1.000000  0.413652 -0.265925 -0.113620
# WindDir        -0.024835 -0.038189   0.413652  1.000000 -0.301516 -0.177474
# Moist          -0.197061  0.131087  -0.265925 -0.301516  1.000000  0.467322
# hPa             0.701251  0.129700  -0.113620 -0.177474  0.467322  1.000000
# DewTemp         0.724719  0.112521  -0.138727 -0.208416  0.503099  0.951086
# CurhPa          0.222051 -0.031903  -0.412288 -0.103286 -0.237073  0.056156
# SeahPa         -0.467182 -0.104219  -0.368680 -0.170085 -0.001743 -0.421292
# Daylight        0.186579 -0.058656   0.228769  0.148210 -0.523527 -0.201734
# DaylightMJ      0.142356 -0.033807   0.314058  0.109759 -0.317358 -0.096839
# SnowCm         -0.294035  0.054685   0.082971  0.001364  0.127469 -0.168987
# Snow3hr        -0.026215  0.503548  -0.005530 -0.026386  0.094745  0.019181
# Clouds_10       0.281126  0.142965  -0.061436 -0.142359  0.379663  0.474827
# MClouds_10      0.220077  0.138757  -0.013789 -0.110144  0.427591  0.470505
# HClouds_100m    0.075946 -0.059762  -0.153849 -0.029602 -0.250345 -0.090221
# Visibility_10m -0.113965 -0.143166   0.091932  0.146546 -0.636418 -0.495520
# SurfaceTemp     0.798374  0.030347   0.008904 -0.003729 -0.185433  0.541449
# FZ_flag        -0.035503 -0.003907  -0.035974 -0.030811  0.056115 -0.012006
#
#                  DewTemp    CurhPa    SeahPa  Daylight  DaylightMJ    SnowCm  \
# Temp            0.724719  0.222051 -0.467182  0.186579    0.142356 -0.294035
# Rain            0.112521 -0.031903 -0.104219 -0.058656   -0.033807  0.054685
# WindSpeed      -0.138727 -0.412288 -0.368680  0.228769    0.314058  0.082971
# Daylight           0.098690 -0.019512
# DaylightMJ         0.062279 -0.016211
# SnowCm            -0.191732  0.021278
# Snow3hr           -0.021238 -0.003466
# Clouds_10          0.197855  0.046001
# MClouds_10         0.165419  0.069703
# HClouds_100m       0.058891 -0.038559
# Visibility_10m    -0.017069 -0.078420
# SurfaceTemp        1.000000 -0.019202
# FZ_flag           -0.019202  1.000000

# %%
def heatmap(data, x, y, size):
    fig, ax = plt.subplots(figsize=(20, 10))
    
    # Mapping from column names to integer coordinates
    x_labels = [v for v in sorted(x.unique())]
    y_labels = [v for v in sorted(y.unique())]
    x_to_num = {p[1]:p[0] for p in enumerate(x_labels)} 
    y_to_num = {p[1]:p[0] for p in enumerate(y_labels)} 
    
    n_colors = 256 # Use 256 colors for the diverging color palette
    palette = sns.diverging_palette(20, 220, n=n_colors) # Create the palette
    color_min, color_max = [-1, 1] # Range of values that will be mapped to the palette, i.e. min and max possible correlation

    def value_to_color(val):
        val_position = float((val - color_min)) / (color_max - color_min) # position of value in the input range, relative to the length of the input range
        ind = int(val_position * (n_colors - 1)) # target index in the color palette
        return palette[ind]

    size_scale = 500
    ax.scatter(
        x=x.map(x_to_num),
        y=y.map(y_to_num),
        s=size * size_scale,
        c=data.apply(value_to_color), # Vector of square color values, mapped to color palette
        marker='s'
    )
    
    # Show column labels on the axes
    ax.set_xticks([x_to_num[v] for v in x_labels])
    ax.set_xticklabels(x_labels, rotation=45, horizontalalignment='right')
    ax.set_yticks([y_to_num[v] for v in y_labels])
    ax.set_yticklabels(y_labels)

# %%
columns = df.columns
corr = df[columns].corr()
corr = pd.melt(corr.reset_index(), id_vars='index') # Unpivot the dataframe, so we can get pair of arrays for x and y
corr.columns = ['x', 'y', 'value']
heatmap(
    data=corr['value'],
    x=corr['x'],
    y=corr['y'],
    size=corr['value'].abs()
)

# %%
def get_Xy(df, X_features, y_col):
    if not isinstance(X_features, list):
        X_features = [X_features]
    if not isinstance(y_col, list):
        y_col = [y_col]
    names = X_features + y_col
    for name in names:
        if name not in df.columns:
            assert False, 'cannot find such column: {}'.format(name)
    X = df.loc[:, X_features]
    y = df[y_col].values
    print('** X : {} rows, {} columns'.format(X.shape[0], X.shape[1]))
    print('** y : {} rows'.format(len(y)))
    return X, y

# %%
def oversampling(df, X_features, y_col, SPLIT_FIRST=True, OVERSAMPLE=False, OVERSAMPLE_RATIO=1.0):
    from sklearn.preprocessing import MinMaxScaler
    from imblearn.over_sampling import SMOTE

    X, y = get_Xy(df, X_features, y_col)
    
    scaler = MinMaxScaler(feature_range=(0, 1))
    scaler.fit_transform(X)
    X = scaler.fit_transform(X)
    
    if not OVERSAMPLE:
        X_tr, X_te, y_tr, y_te = train_test_split(X, y, test_size=0.20, random_state=42)
        df_tr = pd.concat([pd.DataFrame(data=X_tr, columns=X_features), 
                       pd.DataFrame(data=y_tr, columns=[y_col])], axis=1)

        df_te = pd.concat([pd.DataFrame(data=X_te, columns=X_features), 
                           pd.DataFrame(data=y_te, columns=[y_col])], axis=1)
    
        return X_tr, X_te, y_tr, y_te, df_tr, df_te

    # 모델설정
    smote = SMOTE(random_state=1234, sampling_strategy=OVER_SAMPLE_RATIO)

    # train데이터를 넣어 복제함
    if SPLIT_FIRST:
        X_tr, X_te, y_tr, y_te = train_test_split(X, y, test_size=0.20, random_state=42)
        
        X_tr, y_tr = smote.fit_sample(X_tr, list(y_tr))
        X_te, y_te = smote.fit_sample(X_te, list(y_te))

        print('After OverSampling, the shape of train_X: {}'.format(X_tr.shape))
        print('After OverSampling, the shape of train_y: {} \n'.format(y_tr.shape))

        print("After OverSampling, counts of train label '1': {}".format(sum(y_tr==1)))
        print("After OverSampling, counts of train label '0': {}".format(sum(y_tr==0)))

        print('After OverSampling, the shape of test_X: {}'.format(X_te.shape))
        print('After OverSampling, the shape of test_y: {} \n'.format(y_te.shape))

        print("After OverSampling, counts of test label '1': {}".format(sum(y_te==1)))
        print("After OverSampling, counts of test label '0': {}".format(sum(y_te==0)))
    else:
        X, y = smote.fit_sample(X,list(y))

        print('After OverSampling, the shape of X: {}'.format(X.shape))
        print('After OverSampling, the shape of y: {} \n'.format(y.shape))

        print("After OverSampling, counts of y label '1': {}".format(sum(y==1)))
        print("After OverSampling, counts of y label '0': {}".format(sum(y==0)))
        
        X_tr, X_te, y_tr, y_te = train_test_split(X, y, test_size=0.20, random_state=42)
        
        print('After OverSampling, the shape of train_X: {}'.format(X_tr.shape))
        print('After OverSampling, the shape of train_y: {} \n'.format(y_tr.shape))

        print("After OverSampling, counts of train label '1': {}".format(sum(y_tr==1)))
        print("After OverSampling, counts of train label '0': {}".format(sum(y_tr==0)))

        print('After OverSampling, the shape of test_X: {}'.format(X_te.shape))
        print('After OverSampling, the shape of test_y: {} \n'.format(y_te.shape))

        print("After OverSampling, counts of test label '1': {}".format(sum(y_te==1)))
        print("After OverSampling, counts of test label '0': {}".format(sum(y_te==0)))
        
    df_tr = pd.concat([pd.DataFrame(data=X_tr, columns=X_features), 
                       pd.DataFrame(data=y_tr, columns=[y_col])], axis=1)

    df_te = pd.concat([pd.DataFrame(data=X_te, columns=X_features), 
                       pd.DataFrame(data=y_te, columns=[y_col])], axis=1)

    return X_tr, X_te, y_tr, y_te, df_tr, df_te

# %% [markdown]
# ## Statsmodel 를 사용한 로지스틱 회귀

# %%
def build_formula(x_list, y):
    x_str = ' + '.join(x_list)
    return '{} ~ {}'.format(y, x_str)

# %%
x_features = ['Temp', 'Rain', 'WindSpeed', 'Moist', 'hPa', 'DewTemp', 'CurhPa', 
              'SnowCm', 'Snow3hr', 'Clouds_10', 'MClouds_10', 'SurfaceTemp']
y_column = 'FZ_flag'

# %%
x_features = ['Temp', 'Rain', 'WindSpeed', 'Moist', 'hPa', 'DewTemp', 'CurhPa', 
              'SnowCm', 'Snow3hr', 'MClouds_10', 'SurfaceTemp']
y_column = 'FZ_flag'

# %%
x_features = ['Temp', 'Rain', 'WindSpeed', 'WindDir',
       'Moist', 'hPa', 'DewTemp', 'CurhPa', 'SeahPa', 'Daylight', 'DaylightMJ',
       'SnowCm', 'Snow3hr', 'Clouds_10', 'MClouds_10', 
       'HClouds_100m', 'Visibility_10m', 'C(GroundState_Code)', 
       'SurfaceTemp']
y_column = 'FZ_flag'

# %%
X_tr, X_te, y_tr, y_te, df_tr, df_te = oversampling(df, x_features, 'FZ_flag', OVERSAMPLE=False)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-52-825e35f3a82d> in <module>()
# ----> 1 X_tr, X_te, y_tr, y_te, df_tr, df_te = oversampling(df, x_features, 'FZ_flag', OVERSAMPLE=False)
#
# <ipython-input-47-7ad6c3d34dc2> in oversampling(df, X_features, y_col, SPLIT_FIRST, OVERSAMPLE, OVERSAMPLE_RATIO)
#       3     from imblearn.over_sampling import SMOTE
#       4
# ----> 5     X, y = get_Xy(df, X_features, y_col)
#       6
#       7     scaler = MinMaxScaler(feature_range=(0, 1))
#
# <ipython-input-46-d611a1625a17> in get_Xy(df, X_features, y_col)
#       7     for name in names:
#       8         if name not in df.columns:
# ----> 9             assert False, 'cannot find such column: {}'.format(name)
#      10     X = df.loc[:, X_features]
#      11     y = df[y_col].values
#
# AssertionError: cannot find such column: C(CloudDesigns_Abb)

# %%
fm_str = build_formula(x_features, y_column)

# %%
fm_str
# Out:
# 'FZ_flag ~ Temp + Rain + WindSpeed + WindDir + Moist + hPa + DewTemp + CurhPa + SeahPa + Daylight + DaylightMJ + SnowCm + Snow3hr + Clouds_10 + MClouds_10 + C(CloudDesigns_Abb) + HClouds_100m + Visibility_10m + C(GroundState_Code) + SurfaceTemp'

# %%
model_all = sm.Logit.from_formula(fm_str, df)

# %%
result = model_all.fit(maxiter=100, method='bfgs')
# Out:
# /Users/jaeho/anaconda3/lib/python3.6/site-packages/statsmodels/discrete/discrete_model.py:1736: RuntimeWarning: overflow encountered in exp
#   return 1/(1+np.exp(-X))
# /Users/jaeho/anaconda3/lib/python3.6/site-packages/statsmodels/discrete/discrete_model.py:1789: RuntimeWarning: divide by zero encountered in log
#   return np.sum(np.log(self.cdf(q*np.dot(X,params))))
# /Users/jaeho/anaconda3/lib/python3.6/site-packages/statsmodels/discrete/discrete_model.py:1736: RuntimeWarning: overflow encountered in exp
#   return 1/(1+np.exp(-X))
# /Users/jaeho/anaconda3/lib/python3.6/site-packages/statsmodels/discrete/discrete_model.py:1789: RuntimeWarning: divide by zero encountered in log
#   return np.sum(np.log(self.cdf(q*np.dot(X,params))))
# /Users/jaeho/anaconda3/lib/python3.6/site-packages/statsmodels/discrete/discrete_model.py:1736: RuntimeWarning: overflow encountered in exp
#   return 1/(1+np.exp(-X))
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.008434
#          Iterations: 100
#          Function evaluations: 130
#          Gradient evaluations: 127
# /Users/jaeho/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:512: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)

# %%
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                FZ_flag   No. Observations:                29015
# Model:                          Logit   Df Residuals:                    28944
# Method:                           MLE   Df Model:                           70
# Date:                Fri, 14 Feb 2020   Pseudo R-squ.:                  0.4963
# Time:                        00:23:09   Log-Likelihood:                -244.70
# converged:                      False   LL-Null:                       -485.78
# Covariance Type:            nonrobust   LLR p-value:                 7.764e-63
# =================================================================================================
#                                     coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------
# Intercept                        -0.0004     29.355  -1.24e-05      1.000     -57.534      57.534
# C(CloudDesigns_Abb)[T.AcCc]   -5.195e-05     77.813  -6.68e-07      1.000    -152.511     152.511
# C(CloudDesigns_Abb)[T.AcCi]      -0.0099      6.334     -0.002      0.999     -12.424      12.405
# C(CloudDesigns_Abb)[T.AcCs]      -0.0205      4.373     -0.005      0.996      -8.592       8.551
# C(CloudDesigns_Abb)[T.As]        -0.0622      2.810     -0.022      0.982      -5.569       5.445
# C(CloudDesigns_Abb)[T.AsCi]      -0.0003     32.181  -1.01e-05      1.000     -63.074      63.073
# C(CloudDesigns_Abb)[T.AsCs]      -0.0001    174.054  -8.57e-07      1.000    -341.140     341.139
# C(CloudDesigns_Abb)[T.CbNs]      -0.0001    127.111  -1.05e-06      1.000    -249.134     249.133
# C(CloudDesigns_Abb)[T.CbStNs] -4.089e-05    131.913   -3.1e-07      1.000    -258.545     258.545
# C(CloudDesigns_Abb)[T.Cc]     -4.969e-05    441.135  -1.13e-07      1.000    -864.608     864.608
# C(CloudDesigns_Abb)[T.CcCi]   -1.704e-05    122.485  -1.39e-07      1.000    -240.067     240.067
# C(CloudDesigns_Abb)[T.Ci]         0.1146      1.932      0.059      0.953      -3.673       3.902
# C(GroundState_Code)[T.11]        -0.0515      1.163     -0.044      0.965      -2.331       2.228
# C(GroundState_Code)[T.12]        -0.0680      1.574     -0.043      0.966      -3.152       3.016
# C(GroundState_Code)[T.13]         0.3492      0.547      0.639      0.523      -0.722       1.420
# C(GroundState_Code)[T.14]        -0.0028      7.612     -0.000      1.000     -14.923      14.917
# C(GroundState_Code)[T.15]        -0.0027      4.876     -0.001      1.000      -9.559       9.554
# C(GroundState_Code)[T.16]        -0.0140      3.035     -0.005      0.996      -5.963       5.935
# C(GroundState_Code)[T.17]         0.0480      1.551      0.031      0.975      -2.993       3.089
# C(GroundState_Code)[T.18]        -0.0037      5.435     -0.001      0.999     -10.656      10.649
# C(GroundState_Code)[T.19]        -0.1383      1.284     -0.108      0.914      -2.654       2.378
# C(GroundState_Code)[T.2]         -0.0041     24.311     -0.000      1.000     -47.654      47.646
# C(GroundState_Code)[T.3]       -4.98e-05    300.261  -1.66e-07      1.000    -588.500     588.500
# C(GroundState_Code)[T.4]         -0.0683      0.847     -0.081      0.936      -1.729       1.592
# Temp                              0.1915      0.105      1.824      0.068      -0.014       0.397
# Rain                             -0.2971      2.303     -0.129      0.897      -4.811       4.217
# WindSpeed                        -0.4058      0.136     -2.992      0.003      -0.672      -0.140
# WindDir                          -0.0003      0.001     -0.233      0.816      -0.003       0.002
# Moist                             0.0498      0.027      1.814      0.070      -0.004       0.104
# hPa                              -0.9505      0.465     -2.045      0.041      -1.862      -0.039
# DewTemp                          -0.2704      0.153     -1.769      0.077      -0.570       0.029
# CurhPa                           -0.0087      0.006     -1.390      0.164      -0.021       0.004
# SeahPa                            0.0024      0.030      0.081      0.935      -0.056       0.061
# Daylight                          0.0216      0.848      0.026      0.980      -1.640       1.683
# DaylightMJ                       -0.1088      0.623     -0.175      0.861      -1.329       1.112
# SnowCm                           -0.0147      0.021     -0.711      0.477      -0.055       0.026
# Snow3hr                          -0.4232      1.839     -0.230      0.818      -4.028       3.182
# Clouds_10                        -0.0451      0.205     -0.220      0.826      -0.447       0.357
# MClouds_10                        0.2871      0.204      1.406      0.160      -0.113       0.687
# HClouds_100m                     -0.0560      0.064     -0.879      0.379      -0.181       0.069
# Visibility_10m                   -0.0035      0.001     -6.246      0.000      -0.005      -0.002
# SurfaceTemp                       0.0820      0.058      1.420      0.155      -0.031       0.195
# =================================================================================================
#
# Possibly complete quasi-separation: A fraction 0.56 of observations can be
# perfectly predicted. This might indicate that there is complete
# quasi-separation. In this case some parameters will not be identified.
# """

# %%
result.summary2()
# Out:
# <class 'statsmodels.iolib.summary2.Summary'>
# """
#                                   Results: Logit
# ===================================================================================
# Model:                    Logit                  Pseudo R-squared:       0.496
# Dependent Variable:       FZ_flag                AIC:                    631.4019
# Date:                     2020-02-14 00:23       BIC:                    1218.9672
# No. Observations:         29015                  Log-Likelihood:         -244.70
# Df Model:                 70                     LL-Null:                -485.78
# Df Residuals:             28944                  LLR p-value:            7.7642e-63
# Converged:                0.0000                 Scale:                  1.0000
# -----------------------------------------------------------------------------------
#                                Coef.   Std.Err.    z    P>|z|    [0.025     0.975]
# -----------------------------------------------------------------------------------
# Intercept                     -0.0004   29.3546 -0.0000 1.0000   -57.5344   57.5337
# C(CloudDesigns_Abb)[T.AcCc]   -0.0001   77.8133 -0.0000 1.0000  -152.5114  152.5112
# SeahPa                         0.0024    0.0299  0.0814 0.9351    -0.0563    0.0611
# Daylight                       0.0216    0.8476  0.0255 0.9796    -1.6396    1.6829
# DaylightMJ                    -0.1088    0.6227 -0.1747 0.8613    -1.3293    1.1118
# SnowCm                        -0.0147    0.0207 -0.7114 0.4769    -0.0552    0.0258
# Snow3hr                       -0.4232    1.8392 -0.2301 0.8180    -4.0280    3.1816
# Clouds_10                     -0.0451    0.2052 -0.2197 0.8261    -0.4472    0.3571
# MClouds_10                     0.2871    0.2041  1.4064 0.1596    -0.1130    0.6872
# HClouds_100m                  -0.0560    0.0637 -0.8791 0.3794    -0.1807    0.0688
# Visibility_10m                -0.0035    0.0006 -6.2458 0.0000    -0.0045   -0.0024
# SurfaceTemp                    0.0820    0.0577  1.4205 0.1555    -0.0312    0.1952
# ===================================================================================
#
# """

# %%
t = result.pred_table()
print(t)
print("Accuracy:",np.diag(t).sum()/t.sum())
# Out:
# [[2.8944e+04 2.0000e+00]
#  [6.3000e+01 6.0000e+00]]
# Accuracy: 0.9977597794244356

# %%
y_pred_proba = result.predict(df_te)
y_pred = [ 0 if x < 0.5 else 1 for x in y_pred_proba]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-6847b498f7a4> in <module>()
# ----> 1 y_pred_proba = result.predict(df_te)
#       2 y_pred = [ 0 if x < 0.5 else 1 for x in y_pred_proba]
#
# NameError: name 'df_te' is not defined

# %% [markdown]
# ### 구름 모양은 제외

# %%
x_features = ['Temp', 'Rain', 'WindSpeed', 'WindDir',
       'Moist', 'hPa', 'DewTemp', 'CurhPa', 'SeahPa', 'Daylight', 'DaylightMJ',
       'SnowCm', 'Snow3hr', 'Clouds_10', 'MClouds_10', 
       'HClouds_100m', 'Visibility_10m', 'C(GroundState_Code)', 
       'SurfaceTemp']
y_column = 'FZ_flag'

# %%
fm_str = build_formula(x_features, y_column)

# %%
fm_str
# Out:
# 'FZ_flag ~ Temp + Rain + WindSpeed + WindDir + Moist + hPa + DewTemp + CurhPa + SeahPa + Daylight + DaylightMJ + SnowCm + Snow3hr + Clouds_10 + MClouds_10 + HClouds_100m + Visibility_10m + C(GroundState_Code) + SurfaceTemp'

# %%
model2 = sm.Logit.from_formula(fm_str, df)

# %%
result = model2.fit(maxiter=100, method='bfgs')
# Out:
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.009050
#          Iterations: 100
#          Function evaluations: 129
#          Gradient evaluations: 126
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\discrete\discrete_model.py:1789: RuntimeWarning: divide by zero encountered in log
#   return np.sum(np.log(self.cdf(q*np.dot(X,params))))
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\base\model.py:512: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)

# %%
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                FZ_flag   No. Observations:                29015
# Model:                          Logit   Df Residuals:                    28982
# Method:                           MLE   Df Model:                           32
# Date:                Thu, 13 Feb 2020   Pseudo R-squ.:                  0.4595
# Time:                        16:52:45   Log-Likelihood:                -262.58
# converged:                      False   LL-Null:                       -485.78
# Covariance Type:            nonrobust   LLR p-value:                 1.629e-74
# =============================================================================================
#                                 coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# Intercept                    -0.0003     27.299  -9.67e-06      1.000     -53.506      53.505
# C(GroundState_Code)[T.0]     -0.0851      0.980     -0.087      0.931      -2.007       1.836
# C(GroundState_Code)[T.1]      0.0202      1.279      0.016      0.987      -2.486       2.527
# C(GroundState_Code)[T.11]    -0.0648      1.025     -0.063      0.950      -2.075       1.945
# C(GroundState_Code)[T.12]    -0.0582      1.622     -0.036      0.971      -3.237       3.121
# C(GroundState_Code)[T.13]     0.3663      0.547      0.669      0.503      -0.706       1.439
# C(GroundState_Code)[T.14]    -0.0017      9.361     -0.000      1.000     -18.349      18.345
# C(GroundState_Code)[T.15]    -0.0027      4.576     -0.001      1.000      -8.971       8.966
# C(GroundState_Code)[T.16]    -0.0172      2.089     -0.008      0.993      -4.112       4.077
# C(GroundState_Code)[T.17]     0.0439      1.493      0.029      0.977      -2.882       2.970
# C(GroundState_Code)[T.18]    -0.0045      3.816     -0.001      0.999      -7.485       7.476
# C(GroundState_Code)[T.19]    -0.1386      1.215     -0.114      0.909      -2.519       2.242
# C(GroundState_Code)[T.2]     -0.0041     17.164     -0.000      1.000     -33.644      33.636
# C(GroundState_Code)[T.3]  -4.985e-05    264.720  -1.88e-07      1.000    -518.843     518.843
# C(GroundState_Code)[T.4]     -0.0590      0.827     -0.071      0.943      -1.679       1.561
# Temp                          0.1108      0.105      1.053      0.292      -0.095       0.317
# Rain                         -0.3174      1.784     -0.178      0.859      -3.815       3.180
# WindSpeed                    -0.4768      0.134     -3.568      0.000      -0.739      -0.215
# WindDir                       0.0004      0.001      0.315      0.753      -0.002       0.003
# Moist                         0.0276      0.027      1.027      0.304      -0.025       0.080
# hPa                          -0.9109      0.431     -2.113      0.035      -1.756      -0.066
# DewTemp                      -0.2130      0.150     -1.417      0.157      -0.508       0.082
# CurhPa                       -0.0126      0.006     -2.293      0.022      -0.023      -0.002
# SeahPa                        0.0091      0.028      0.327      0.744      -0.046       0.064
# Daylight                      0.0244      0.849      0.029      0.977      -1.639       1.688
# DaylightMJ                   -0.0818      0.611     -0.134      0.893      -1.279       1.115
# SnowCm                       -0.0170      0.018     -0.928      0.353      -0.053       0.019
# Snow3hr                      -0.4399      1.490     -0.295      0.768      -3.360       2.480
# Clouds_10                    -0.3733      0.139     -2.694      0.007      -0.645      -0.102
# MClouds_10                    0.5735      0.140      4.100      0.000       0.299       0.848
# HClouds_100m                 -0.0607      0.040     -1.529      0.126      -0.138       0.017
# Visibility_10m               -0.0037      0.001     -6.624      0.000      -0.005      -0.003
# SurfaceTemp                   0.1073      0.055      1.943      0.052      -0.001       0.215
# =============================================================================================
#
# Possibly complete quasi-separation: A fraction 0.57 of observations can be
# perfectly predicted. This might indicate that there is complete
# quasi-separation. In this case some parameters will not be identified.
# """

# %%
result.summary2()
# Out:
# <class 'statsmodels.iolib.summary2.Summary'>
# """
#                                Results: Logit
# ============================================================================
# Model:                   Logit               Pseudo R-squared:    0.459
# Dependent Variable:      FZ_flag             AIC:                 591.1700
# Date:                    2020-02-13 16:52    BIC:                 864.2637
# No. Observations:        29015               Log-Likelihood:      -262.58
# Df Model:                32                  LL-Null:             -485.78
# Df Residuals:            28982               LLR p-value:         1.6292e-74
# Converged:               0.0000              Scale:               1.0000
# ----------------------------------------------------------------------------
#                            Coef.  Std.Err.    z    P>|z|    [0.025   0.975]
# ----------------------------------------------------------------------------
# Intercept                 -0.0003  27.2991 -0.0000 1.0000  -53.5056  53.5051
# C(GroundState_Code)[T.0]  -0.0851   0.9804 -0.0869 0.9308   -2.0067   1.8364
# C(GroundState_Code)[T.1]   0.0202   1.2788  0.0158 0.9874   -2.4861   2.5266
# C(GroundState_Code)[T.11] -0.0648   1.0255 -0.0632 0.9496   -2.0747   1.9451
# C(GroundState_Code)[T.12] -0.0582   1.6219 -0.0359 0.9714   -3.2371   3.1206
# C(GroundState_Code)[T.13]  0.3663   0.5473  0.6693 0.5033   -0.7064   1.4391
# C(GroundState_Code)[T.14] -0.0017   9.3609 -0.0002 0.9999  -18.3487  18.3453
# C(GroundState_Code)[T.15] -0.0027   4.5757 -0.0006 0.9995   -8.9710   8.9656
# C(GroundState_Code)[T.16] -0.0172   2.0890 -0.0083 0.9934   -4.1115   4.0770
# C(GroundState_Code)[T.17]  0.0439   1.4927  0.0294 0.9765   -2.8818   2.9696
# C(GroundState_Code)[T.18] -0.0045   3.8164 -0.0012 0.9991   -7.4845   7.4756
# C(GroundState_Code)[T.19] -0.1386   1.2146 -0.1141 0.9092   -2.5192   2.2421
# C(GroundState_Code)[T.2]  -0.0041  17.1636 -0.0002 0.9998  -33.6442  33.6359
# C(GroundState_Code)[T.3]  -0.0000 264.7205 -0.0000 1.0000 -518.8426 518.8425
# C(GroundState_Code)[T.4]  -0.0590   0.8266 -0.0714 0.9431   -1.6790   1.5610
# Temp                       0.1108   0.1053  1.0531 0.2923   -0.0954   0.3171
# Rain                      -0.3174   1.7844 -0.1779 0.8588   -3.8147   3.1800
# WindSpeed                 -0.4768   0.1336 -3.5682 0.0004   -0.7388  -0.2149
# WindDir                    0.0004   0.0012  0.3149 0.7528   -0.0019   0.0027
# Moist                      0.0276   0.0268  1.0269 0.3045   -0.0250   0.0801
# hPa                       -0.9109   0.4311 -2.1132 0.0346   -1.7557  -0.0661
# DewTemp                   -0.2130   0.1504 -1.4165 0.1566   -0.5077   0.0817
# CurhPa                    -0.0126   0.0055 -2.2931 0.0218   -0.0234  -0.0018
# SeahPa                     0.0091   0.0280  0.3267 0.7439   -0.0457   0.0640
# Daylight                   0.0244   0.8488  0.0287 0.9771   -1.6393   1.6881
# DaylightMJ                -0.0818   0.6109 -0.1339 0.8934   -1.2792   1.1155
# SnowCm                    -0.0170   0.0183 -0.9283 0.3533   -0.0529   0.0189
# Snow3hr                   -0.4399   1.4900 -0.2952 0.7678   -3.3602   2.4804
# Clouds_10                 -0.3733   0.1386 -2.6941 0.0071   -0.6449  -0.1017
# MClouds_10                 0.5735   0.1399  4.1001 0.0000    0.2993   0.8476
# HClouds_100m              -0.0607   0.0397 -1.5293 0.1262   -0.1384   0.0171
# Visibility_10m            -0.0037   0.0006 -6.6239 0.0000   -0.0048  -0.0026
# SurfaceTemp                0.1073   0.0552  1.9428 0.0520   -0.0009   0.2155
# ============================================================================
#
# """

# %% [markdown]
# ### 지면상태도 제외

# %%
x_features = ['Temp', 'Rain', 'WindSpeed', 'WindDir',
       'Moist', 'hPa', 'DewTemp', 'CurhPa', 'SeahPa', 'Daylight', 'DaylightMJ',
       'SnowCm', 'Snow3hr', 'Clouds_10', 'MClouds_10', 
       'HClouds_100m', 'Visibility_10m',  
       'SurfaceTemp']
y_column = 'FZ_flag'

# %%
X_tr, X_te, y_tr, y_te, df_tr, df_te = oversampling(df, x_features, y_column)
# Out:
# ** X : 29015 rows, 18 columns
# ** y : 29015 rows

# %%
fm_str = build_formula(x_features, y_column)

# %%
fm_str
# Out:
# 'FZ_flag ~ Temp + Rain + WindSpeed + WindDir + Moist + hPa + DewTemp + CurhPa + SeahPa + Daylight + DaylightMJ + SnowCm + Snow3hr + Clouds_10 + MClouds_10 + HClouds_100m + Visibility_10m + SurfaceTemp'

# %%
model3 = sm.Logit.from_formula(fm_str, df)

# %%
result = model3.fit(maxiter=200, method='bfgs')
# Out:
# /Users/jaeho/anaconda3/lib/python3.6/site-packages/statsmodels/discrete/discrete_model.py:1736: RuntimeWarning: overflow encountered in exp
#   return 1/(1+np.exp(-X))
# /Users/jaeho/anaconda3/lib/python3.6/site-packages/statsmodels/discrete/discrete_model.py:1789: RuntimeWarning: divide by zero encountered in log
#   return np.sum(np.log(self.cdf(q*np.dot(X,params))))
# /Users/jaeho/anaconda3/lib/python3.6/site-packages/statsmodels/discrete/discrete_model.py:1736: RuntimeWarning: overflow encountered in exp
#   return 1/(1+np.exp(-X))
# /Users/jaeho/anaconda3/lib/python3.6/site-packages/statsmodels/discrete/discrete_model.py:1789: RuntimeWarning: divide by zero encountered in log
#   return np.sum(np.log(self.cdf(q*np.dot(X,params))))
# /Users/jaeho/anaconda3/lib/python3.6/site-packages/statsmodels/discrete/discrete_model.py:1736: RuntimeWarning: overflow encountered in exp
#   return 1/(1+np.exp(-X))
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.008762
#          Iterations: 200
#          Function evaluations: 231
#          Gradient evaluations: 228
# /Users/jaeho/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:512: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)

# %%
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                FZ_flag   No. Observations:                29015
# Model:                          Logit   Df Residuals:                    28996
# Method:                           MLE   Df Model:                           18
# Date:                Fri, 14 Feb 2020   Pseudo R-squ.:                  0.4767
# Time:                        00:32:46   Log-Likelihood:                -254.22
# converged:                      False   LL-Null:                       -485.78
# Covariance Type:            nonrobust   LLR p-value:                 5.789e-87
# ==================================================================================
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# Intercept          0.6889     28.207      0.024      0.981     -54.596      55.973
# Temp               0.2289      0.103      2.229      0.026       0.028       0.430
# Rain               0.3482      0.320      1.089      0.276      -0.278       0.975
# WindSpeed         -0.3903      0.126     -3.087      0.002      -0.638      -0.142
# WindDir            0.0003      0.001      0.219      0.826      -0.002       0.003
# Moist              0.0465      0.026      1.775      0.076      -0.005       0.098
# hPa               -3.2634      0.769     -4.241      0.000      -4.771      -1.755
# DewTemp            0.2811      0.220      1.275      0.202      -0.151       0.713
# CurhPa            -0.0146      0.006     -2.538      0.011      -0.026      -0.003
# SeahPa             0.0212      0.029      0.733      0.463      -0.035       0.078
# Daylight          -0.1361      0.843     -0.162      0.872      -1.788       1.516
# DaylightMJ        -0.3711      0.643     -0.577      0.564      -1.632       0.890
# SnowCm            -0.0194      0.019     -1.032      0.302      -0.056       0.017
# Snow3hr          -12.7411     16.463     -0.774      0.439     -45.007      19.525
# Clouds_10         -0.3352      0.130     -2.588      0.010      -0.589      -0.081
# MClouds_10         0.5346      0.131      4.079      0.000       0.278       0.791
# HClouds_100m      -0.0787      0.043     -1.836      0.066      -0.163       0.005
# Visibility_10m    -0.0034      0.001     -6.090      0.000      -0.004      -0.002
# SurfaceTemp        0.0899      0.053      1.700      0.089      -0.014       0.193
# ==================================================================================
#
# Possibly complete quasi-separation: A fraction 0.61 of observations can be
# perfectly predicted. This might indicate that there is complete
# quasi-separation. In this case some parameters will not be identified.
# """

# %%
result.summary2()
# Out:
# <class 'statsmodels.iolib.summary2.Summary'>
# """
#                          Results: Logit
# =================================================================
# Model:              Logit            Pseudo R-squared: 0.477
# Dependent Variable: FZ_flag          AIC:              546.4414
# Date:               2020-02-14 00:32 BIC:              703.6772
# No. Observations:   29015            Log-Likelihood:   -254.22
# Df Model:           18               LL-Null:          -485.78
# Df Residuals:       28996            LLR p-value:      5.7888e-87
# Converged:          0.0000           Scale:            1.0000
# -----------------------------------------------------------------
#                  Coef.   Std.Err.    z    P>|z|   [0.025   0.975]
# -----------------------------------------------------------------
# Intercept         0.6889  28.2069  0.0244 0.9805 -54.5956 55.9733
# Temp              0.2289   0.1027  2.2294 0.0258   0.0277  0.4301
# Rain              0.3482   0.3197  1.0892 0.2761  -0.2784  0.9748
# WindSpeed        -0.3903   0.1264 -3.0868 0.0020  -0.6382 -0.1425
# WindDir           0.0003   0.0012  0.2193 0.8264  -0.0021  0.0026
# Moist             0.0465   0.0262  1.7754 0.0758  -0.0048  0.0979
# hPa              -3.2634   0.7694 -4.2413 0.0000  -4.7714 -1.7553
# DewTemp           0.2811   0.2205  1.2752 0.2022  -0.1510  0.7132
# CurhPa           -0.0146   0.0058 -2.5378 0.0112  -0.0259 -0.0033
# SeahPa            0.0212   0.0289  0.7335 0.4633  -0.0354  0.0778
# Daylight         -0.1361   0.8427 -0.1615 0.8717  -1.7877  1.5155
# DaylightMJ       -0.3711   0.6432 -0.5770 0.5640  -1.6317  0.8895
# SnowCm           -0.0194   0.0188 -1.0317 0.3022  -0.0563  0.0175
# Snow3hr         -12.7411  16.4627 -0.7739 0.4390 -45.0074 19.5251
# Clouds_10        -0.3352   0.1295 -2.5876 0.0097  -0.5890 -0.0813
# MClouds_10        0.5346   0.1310  4.0794 0.0000   0.2777  0.7914
# HClouds_100m     -0.0787   0.0429 -1.8358 0.0664  -0.1628  0.0053
# Visibility_10m   -0.0034   0.0006 -6.0901 0.0000  -0.0044 -0.0023
# SurfaceTemp       0.0899   0.0529  1.7003 0.0891  -0.0137  0.1935
# =================================================================
#
# """

# %%
t = result.pred_table()
print(t)
print("Accuracy:",np.diag(t).sum()/t.sum())
# Out:
# [[2.8944e+04 2.0000e+00]
#  [6.5000e+01 4.0000e+00]]
# Accuracy: 0.9976908495605721

# %%
y_pred_proba = result.predict(df_te)
y_pred = [ 0 if x < 0.5 else 1 for x in y_pred_proba]

# %%
score = accuracy_score(y_te, y_pred)
score
# Out:
# 0.27933827330691025

# %% [markdown]
# ### 변수 scaling
#
# * MinMaxScaler

# %%
feature_cols = ['Date', 'Temp', 'Rain', 'WindSpeed', 'WindDir',
       'Moist', 'hPa', 'DewTemp', 'CurhPa', 'SeahPa', 'Daylight', 'DaylightMJ',
       'SnowCm', 'Snow3hr', 'Clouds_10', 'MClouds_10', 'CloudDesigns_Abb',
       'HClouds_100m', 'Visibility_10m', 'GroundState_Code', 'PhenomenaNo',
       'SurfaceTemp']
feature_cols_numeric_only = ['Temp', 'Rain', 'WindSpeed', 'WindDir',
       'Moist', 'hPa', 'DewTemp', 'CurhPa', 'SeahPa', 'Daylight', 'DaylightMJ',
       'SnowCm', 'Snow3hr', 'Clouds_10', 'MClouds_10',
       'HClouds_100m', 'Visibility_10m', 
       'SurfaceTemp']

# %%
X = df.loc[:, feature_cols_numeric_only]
y = df['FZ_flag'].values

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler(feature_range=(0, 1))
scaler.fit_transform(X)
X_sc = scaler.fit_transform(X)

# %%
df_X_sc = pd.DataFrame(data=X_sc, columns=feature_cols_numeric_only)
df_y = pd.DataFrame(data=y, columns=['FZ_flag'])

# %%
df_sc = pd.concat([df_X_sc, df_y], axis=1)

# %%
df_sc.corr()
# Out:
#                     Temp      Rain  WindSpeed   WindDir     Moist       hPa  \
# Temp            1.000000  0.036713   0.024753 -0.024835 -0.197061  0.701251
#                  Snow3hr  Clouds_10  MClouds_10  HClouds_100m  Visibility_10m  \
# Temp           -0.026215   0.281126    0.220077      0.075946       -0.113965
# Rain            0.503548   0.142965    0.138757     -0.059762       -0.143166
# WindSpeed      -0.005530  -0.061436   -0.013789     -0.153849        0.091932
# WindDir        -0.026386  -0.142359   -0.110144     -0.029602        0.146546
# Moist           0.094745   0.379663    0.427591     -0.250345       -0.636418
# hPa             0.019181   0.474827    0.470505     -0.090221       -0.495520
# DewTemp         0.032787   0.498142    0.480105     -0.096094       -0.529956
# CurhPa         -0.048695  -0.058329   -0.067530      0.388883        0.165913
# SeahPa         -0.036025  -0.269215   -0.270659      0.091693        0.223693
# Daylight       -0.040419  -0.307247   -0.302629      0.030372        0.293732
# DaylightMJ     -0.019983  -0.104911   -0.122640     -0.030173        0.120958
# SnowCm          0.134067   0.034466    0.050577     -0.111860       -0.085195
# Snow3hr         1.000000   0.098364    0.101580     -0.052889       -0.119284
# Clouds_10       0.098364   1.000000    0.823258     -0.056796       -0.513472
# MClouds_10      0.101580   0.823258    1.000000     -0.088339       -0.523749
# HClouds_100m   -0.052889  -0.056796   -0.088339      1.000000        0.208346
# Visibility_10m -0.119284  -0.513472   -0.523749      0.208346        1.000000
# SurfaceTemp    -0.021238   0.197855    0.165419      0.058891       -0.017069
# FZ_flag        -0.003466   0.046001    0.069703     -0.038559       -0.078420
#
#                 SurfaceTemp   FZ_flag
# Temp               0.798374 -0.035503
# Rain               0.030347 -0.003907
# WindSpeed          0.008904 -0.035974
# WindDir           -0.003729 -0.030811
# Moist             -0.185433  0.056115
# hPa                0.541449 -0.012006
# DewTemp            0.542589 -0.003212
# CurhPa             0.202784 -0.031168
# SeahPa            -0.410426  0.022313
# Daylight           0.098690 -0.019512
# DaylightMJ         0.062279 -0.016211
# SnowCm            -0.191732  0.021278
# Snow3hr           -0.021238 -0.003466
# Clouds_10          0.197855  0.046001
# MClouds_10         0.165419  0.069703
# HClouds_100m       0.058891 -0.038559
# Visibility_10m    -0.017069 -0.078420
# SurfaceTemp        1.000000 -0.019202
# FZ_flag           -0.019202  1.000000

# %%
columns = df_sc.columns
corr = df_sc[columns].corr()
corr = pd.melt(corr.reset_index(), id_vars='index') # Unpivot the dataframe, so we can get pair of arrays for x and y
corr.columns = ['x', 'y', 'value']
heatmap(
    data=corr['value'],
    x=corr['x'],
    y=corr['y'],
    size=corr['value'].abs()
)

# %%
x_features = ['Temp', 'Rain', 'WindSpeed', 'Moist', 'hPa', 'DewTemp', 'CurhPa', 
              'SnowCm', 'MClouds_10', 'SurfaceTemp']
y_column = 'FZ_flag'

# %%
fm_str = build_formula(x_features, y_column)

# %%
fm_str
# Out:
# 'FZ_flag ~ Temp + Rain + WindSpeed + Moist + hPa + DewTemp + CurhPa + SnowCm + MClouds_10 + SurfaceTemp'

# %%
model_sc = sm.Logit.from_formula(fm_str, df_sc)

# %%
result = model_sc.fit(maxiter=100)
# Out:
# Optimization terminated successfully.
#          Current function value: 0.010201
#          Iterations 14

# %%
print(result.summary2())
# Out:
#                          Results: Logit
# =================================================================
# Model:              Logit            Pseudo R-squared: 0.391
# Dependent Variable: FZ_flag          AIC:              613.9739
# Date:               2020-02-12 23:54 BIC:              705.0051
# No. Observations:   29015            Log-Likelihood:   -295.99
# Df Model:           10               LL-Null:          -485.78
# Df Residuals:       29004            LLR p-value:      2.0728e-75
# Converged:          1.0000           Scale:            1.0000
# No. Iterations:     14.0000
# -----------------------------------------------------------------
#                 Coef.   Std.Err.    z    P>|z|   [0.025   0.975]
# -----------------------------------------------------------------
# Intercept      -21.5547   2.6321 -8.1892 0.0000 -26.7135 -16.3959
# Temp            10.1937   3.8185  2.6695 0.0076   2.7095  17.6779
# Rain           -32.2146  33.6378 -0.9577 0.3382 -98.1433  33.7142
# WindSpeed       -5.7380   1.7840 -3.2164 0.0013  -9.2345  -2.2414
# Moist           13.2998   1.9631  6.7747 0.0000   9.4521  17.1475
# hPa            -50.9780  11.6958 -4.3587 0.0000 -73.9012 -28.0547
# DewTemp         11.6161   9.4479  1.2295 0.2189  -6.9014  30.1335
# CurhPa          -0.9928   0.5687 -1.7456 0.0809  -2.1074   0.1219
# SnowCm          -2.1001   1.1814 -1.7776 0.0755  -4.4155   0.2154
# MClouds_10       4.4234   0.4815  9.1859 0.0000   3.4796   5.3672
# SurfaceTemp      7.9632   2.6285  3.0295 0.0024   2.8114  13.1151
# =================================================================

# %% [markdown]
# ## sci-kit learn Logistic Regression (all columns)

# %%
df_seoul = df.loc[df['Office_Name']=='서울']

# %%
feature_cols = ['Date', 'Temp', 'Rain', 'WindSpeed', 'WindDir',
       'Moist', 'hPa', 'DewTemp', 'CurhPa', 'SeahPa', 'Daylight', 'DaylightMJ',
       'SnowCm', 'Snow3hr', 'Clouds_10', 'MClouds_10', 'CloudDesigns_Abb',
       'HClouds_100m', 'Visibility_10m', 'GroundState_Code', 'PhenomenaNo',
       'SurfaceTemp']
feature_cols_numeric_only = ['Temp', 'Rain', 'WindSpeed', 'WindDir',
       'Moist', 'hPa', 'DewTemp', 'CurhPa', 'SeahPa', 'Daylight', 'DaylightMJ',
       'SnowCm', 'Snow3hr', 'Clouds_10', 'MClouds_10',
       'HClouds_100m', 'Visibility_10m', 
       'SurfaceTemp']

# %%
X = df_seoul.loc[:, feature_cols_numeric_only]
y = df_seoul['FZ_flag'].values

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler(feature_range=(0, 1))
scaler.fit_transform(X)
X_sc = scaler.fit_transform(X)

# %%
df_X_sc = pd.DataFrame(data=X_sc, columns=['Temp', 'Rain', 'WindSpeed', 'WindDir',
       'Moist', 'hPa', 'DewTemp', 'CurhPa', 'SeahPa', 'Daylight', 'DaylightMJ',
       'SnowCm', 'Snow3hr', 'Clouds_10', 'MClouds_10',
       'HClouds_100m', 'Visibility_10m', 
       'SurfaceTemp'])
df_y = pd.DataFrame(data=y, columns=['FZ_flag'])

# %%
df_sc = pd.concat([df_X_sc, df_y], axis=1)

# %%
df_sc.shape
# Out:
# (7248, 19)

# %%
df_seoul.corr()
# Out:
#                     Temp      Rain  WindSpeed   WindDir     Moist       hPa  \
# Temp            1.000000  0.032257   0.019254 -0.155702  0.038879  0.720154
# Rain            0.032257  1.000000   0.009126 -0.048988  0.171938  0.138139
# WindSpeed       0.019254  0.009126   1.000000  0.319842 -0.248831 -0.105800
# WindDir        -0.155702 -0.048988   0.319842  1.000000 -0.254369 -0.222321
# WindSpeed       0.013530   0.001865    0.044952     -0.015160        0.183956
# WindDir         0.016538  -0.217571   -0.178856      0.002740        0.137289
# Moist           0.028132   0.420218    0.478618     -0.255239       -0.665075
# hPa             0.073202   0.456125    0.472982     -0.173115       -0.571944
# DewTemp         0.077805   0.481722    0.474819     -0.178539       -0.587438
# CurhPa         -0.251224  -0.346543   -0.351055      0.118181        0.297254
# SeahPa         -0.248810  -0.353219   -0.355209      0.117960        0.301296
# Daylight       -0.013863  -0.337124   -0.324267      0.059031        0.249289
# DaylightMJ     -0.002336  -0.182305   -0.202241      0.055827        0.185142
# SnowCm          0.019588   0.000138    0.048270     -0.048416       -0.107237
# Snow3hr         1.000000   0.043213    0.006996      0.128868       -0.090766
# Clouds_10       0.043213   1.000000    0.812602     -0.100026       -0.424591
# MClouds_10      0.006996   0.812602    1.000000     -0.119960       -0.427364
# HClouds_100m    0.128868  -0.100026   -0.119960      1.000000        0.150911
# Visibility_10m -0.090766  -0.424591   -0.427364      0.150911        1.000000
# SurfaceTemp     0.073599   0.221934    0.171586     -0.034950       -0.088745
# FZ_flag        -0.000041   0.044751    0.035549     -0.014466        0.004965
#
#                 SurfaceTemp   FZ_flag
# Temp               0.800572  0.001352
# Rain               0.026652  0.003894
# WindSpeed          0.165809  0.033008
# WindDir            0.017539 -0.035058
# Moist             -0.064998 -0.015787
# hPa                0.526931 -0.018270
# DewTemp            0.524533 -0.014364
# CurhPa            -0.379977 -0.003954
# SeahPa            -0.406488 -0.003873
# Daylight           0.164379 -0.017892
# DaylightMJ         0.255540 -0.018990
# SnowCm            -0.183176 -0.010047
# Snow3hr            0.073599 -0.000041
# Clouds_10          0.221934  0.044751
# MClouds_10         0.171586  0.035549
# HClouds_100m      -0.034950 -0.014466
# Visibility_10m    -0.088745  0.004965
# SurfaceTemp        1.000000 -0.007548
# FZ_flag           -0.007548  1.000000

# %%
def heatmap(data, x, y, size):
    fig, ax = plt.subplots(figsize=(20, 10))
    
    # Mapping from column names to integer coordinates
    x_labels = [v for v in sorted(x.unique())]
    y_labels = [v for v in sorted(y.unique())]
    x_to_num = {p[1]:p[0] for p in enumerate(x_labels)} 
    y_to_num = {p[1]:p[0] for p in enumerate(y_labels)} 
    
    n_colors = 256 # Use 256 colors for the diverging color palette
    palette = sns.diverging_palette(20, 220, n=n_colors) # Create the palette
    color_min, color_max = [-1, 1] # Range of values that will be mapped to the palette, i.e. min and max possible correlation

    def value_to_color(val):
        val_position = float((val - color_min)) / (color_max - color_min) # position of value in the input range, relative to the length of the input range
        ind = int(val_position * (n_colors - 1)) # target index in the color palette
        return palette[ind]

    size_scale = 500
    ax.scatter(
        x=x.map(x_to_num),
        y=y.map(y_to_num),
        s=size * size_scale,
        c=data.apply(value_to_color), # Vector of square color values, mapped to color palette
        marker='s'
    )
    
    # Show column labels on the axes
    ax.set_xticks([x_to_num[v] for v in x_labels])
    ax.set_xticklabels(x_labels, rotation=45, horizontalalignment='right')
    ax.set_yticks([y_to_num[v] for v in y_labels])
    ax.set_yticklabels(y_labels)

# %%
columns = feature_cols + ['FZ_flag'] 
corr = df_seoul[columns].corr()
corr = pd.melt(corr.reset_index(), id_vars='index') # Unpivot the dataframe, so we can get pair of arrays for x and y
corr.columns = ['x', 'y', 'value']
heatmap(
    data=corr['value'],
    x=corr['x'],
    y=corr['y'],
    size=corr['value'].abs()
)

# %%
logreg = LogisticRegression().fit(X, y)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)

# %%
logreg.coef_
# Out:
# array([[ 5.10160268e-01,  2.22232703e-02,  1.36405178e+00,
#         -6.56726769e-02, -1.88689215e-03, -9.28854283e-01,
#         -3.03684008e-01, -2.72186803e-02,  1.97856468e-02,
#         -2.58480413e-01, -9.73480623e-01, -9.36081980e-01,
#          4.49098216e-01,  1.28029747e+00,  5.29565796e-01,
#         -1.30460779e+00,  6.14288803e-05, -2.45787329e-01]])

# %% [markdown]
# ## statsmodel

# %%
import statsmodels.api as sm

# %%
df_seoul.isnull().sum()
# Out:
# Office              0
# Office_Name         0
# Date                0
# Temp                0
# Rain                0
# WindSpeed           0
# WindDir             0
# Moist               0
# hPa                 0
# DewTemp             0
# CurhPa              0
# SeahPa              0
# Daylight            0
# DaylightMJ          0
# SnowCm              0
# Snow3hr             0
# Clouds_10           0
# MClouds_10          0
# CloudDesigns_Abb    0
# HClouds_100m        0
# Visibility_10m      0
# GroundState_Code    0
# PhenomenaNo         0
# SurfaceTemp         0
# FZ_flag             0
# dtype: int64

# %%
df_seoul.dtypes
# Out:
# Office               object
# Office_Name          object
# Date                 object
# Temp                float64
# Rain                float64
# WindSpeed           float64
# WindDir               int64
# Moist               float64
# hPa                 float64
# DewTemp             float64
# CurhPa              float64
# SeahPa              float64
# Daylight            float64
# DaylightMJ          float64
# SnowCm              float64
# Snow3hr             float64
# Clouds_10           float64
# MClouds_10          float64
# CloudDesigns_Abb     object
# HClouds_100m        float64
# Visibility_10m      float64
# GroundState_Code     object
# PhenomenaNo          object
# SurfaceTemp         float64
# FZ_flag               int64
# dtype: object

# %%
def build_formula(x_list, y):
    x_str = ' + '.join(x_list)
    return '{} ~ {}'.format(y, x_str)

# %%
fm_str = build_formula(['Temp', 'Rain', 'WindSpeed', 
                        'Moist', 'hPa', 'DewTemp', 'CurhPa', 'SeahPa', 
                        'SnowCm', 'Snow3hr', 'Clouds_10', 'MClouds_10',
                        'HClouds_100m', 'Visibility_10m', 
                        'SurfaceTemp'], 'FZ_flag')

# %% [markdown]
# ## HClouds_100m, SeahPa --> singular matrix

# %%
fm_str = build_formula(['Temp', 'Rain', 'WindSpeed', 
                        'Moist', 'hPa', 'DewTemp', 'CurhPa', 
                        'SnowCm', 'Snow3hr', 'Clouds_10', 'MClouds_10',
                        'SurfaceTemp'], 'FZ_flag')

# %%
model = sm.Logit.from_formula(fm_str, df_seoul)

# %%
result = model.fit(maxiter=100)
print(result.summary())
# Out:
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.002886
#          Iterations: 100
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                FZ_flag   No. Observations:                 7248
# Model:                          Logit   Df Residuals:                     7235
# Method:                           MLE   Df Model:                           12
# Date:                Wed, 12 Feb 2020   Pseudo R-squ.:                  0.6238
# Time:                        14:30:27   Log-Likelihood:                -20.915
# converged:                      False   LL-Null:                       -55.595
# Covariance Type:            nonrobust   LLR p-value:                 4.221e-10
# ===============================================================================
#                   coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept    -172.9011   2.28e+04     -0.008      0.994   -4.49e+04    4.46e+04
# Temp            0.8538      0.436      1.960      0.050   -4.93e-05       1.708
# Rain            1.1311      0.838      1.350      0.177      -0.511       2.773
# WindSpeed       1.1751      0.514      2.287      0.022       0.168       2.182
# Moist           0.0798      0.058      1.366      0.172      -0.035       0.194
# hPa           -10.8264      5.256     -2.060      0.039     -21.129      -0.524
# DewTemp         2.2538      1.262      1.786      0.074      -0.219       4.727
# CurhPa          0.0383      0.105      0.365      0.715      -0.167       0.244
# SnowCm       -123.5363   7571.384     -0.016      0.987    -1.5e+04    1.47e+04
# Snow3hr         0.6069      1.042      0.583      0.560      -1.435       2.648
# Clouds_10      17.6457   2284.205      0.008      0.994   -4459.314    4494.605
# MClouds_10      0.0388      0.152      0.255      0.799      -0.260       0.337
# SurfaceTemp    -1.1140      0.559     -1.992      0.046      -2.210      -0.018
# ===============================================================================
#
# Possibly complete quasi-separation: A fraction 0.97 of observations can be
# perfectly predicted. This might indicate that there is complete
# quasi-separation. In this case some parameters will not be identified.
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\base\model.py:512: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)

# %%
print(result.summary2())
# Out:
#                             Results: Logit
# ======================================================================
# Model:                 Logit             Pseudo R-squared:  0.624
# Dependent Variable:    FZ_flag           AIC:               67.8305
# Date:                  2020-02-12 14:35  BIC:               157.3808
# No. Observations:      7248              Log-Likelihood:    -20.915
# Df Model:              12                LL-Null:           -55.595
# Df Residuals:          7235              LLR p-value:       4.2214e-10
# Converged:             0.0000            Scale:             1.0000
# No. Iterations:        100.0000
# ----------------------------------------------------------------------
#               Coef.    Std.Err.     z    P>|z|     [0.025     0.975]
# ----------------------------------------------------------------------
# Intercept   -172.9011 22842.3127 -0.0076 0.9940 -44943.0114 44597.2092
# Temp           0.8538     0.4357  1.9599 0.0500     -0.0000     1.7077
# Rain           1.1311     0.8380  1.3498 0.1771     -0.5113     2.7735
# WindSpeed      1.1751     0.5139  2.2866 0.0222      0.1679     2.1824
# Moist          0.0798     0.0584  1.3665 0.1718     -0.0347     0.1943
# hPa          -10.8264     5.2563 -2.0597 0.0394    -21.1286    -0.5243
# DewTemp        2.2538     1.2619  1.7861 0.0741     -0.2194     4.7270
# CurhPa         0.0383     0.1049  0.3653 0.7149     -0.1672     0.2438
# SnowCm      -123.5363  7571.3836 -0.0163 0.9870 -14963.1755 14716.1029
# Snow3hr        0.6069     1.0416  0.5826 0.5601     -1.4346     2.6484
# Clouds_10     17.6457  2284.2049  0.0077 0.9938  -4459.3136  4494.6050
# MClouds_10     0.0388     0.1523  0.2549 0.7988     -0.2596     0.3373
# SurfaceTemp   -1.1140     0.5591 -1.9924 0.0463     -2.2099    -0.0181
# ======================================================================

# %%
print(np.exp(result.params)) # 오즈 비(Odds Ratio) 출력
# Out:
# Intercept      8.128348e-76
# Temp           2.348664e+00
# Rain           3.098996e+00
# WindSpeed      3.238595e+00
# Moist          1.083084e+00
# hPa            1.986705e-05
# DewTemp        9.523855e+00
# CurhPa         1.039044e+00
# SnowCm         2.232953e-54
# Snow3hr        1.834711e+00
# Clouds_10      4.607180e+07
# MClouds_10     1.039571e+00
# SurfaceTemp    3.282328e-01
# dtype: float64

# %% [markdown]
# ## after scaling

# %%
df_sc.head()
# Out:
#        Temp  Rain  WindSpeed   WindDir     Moist       hPa   DewTemp  \
# 0  0.471429   0.0   0.000000  0.000000  0.655172  0.248408  0.564593
# 1  0.485714   0.0   0.240741  0.750000  0.643678  0.248408  0.564593
# 2  0.485714   0.0   0.074074  0.888889  0.712644  0.248408  0.564593
# 3  0.482857   0.0   0.157407  0.805556  0.735632  0.292994  0.605263
# 4  0.482857   0.0   0.129630  0.750000  0.747126  0.292994  0.605263
#
#      CurhPa    SeahPa  Daylight  DaylightMJ  SnowCm  Snow3hr  Clouds_10  \
# 0  0.742459  0.734234       0.0         0.0     0.0      0.0        0.5
# 1  0.742459  0.734234       0.0         0.0     0.0      0.0        0.5
# 2  0.742459  0.734234       0.0         0.0     0.0      0.0        0.5
# 3  0.723898  0.713964       0.0         0.0     0.0      0.0        0.6
# 4  0.723898  0.713964       0.0         0.0     0.0      0.0        0.6
#
#    MClouds_10  HClouds_100m  Visibility_10m  SurfaceTemp  FZ_flag
# 0         0.0      0.076923        0.397993     0.157068        0
# 1         0.0      0.076923        0.397993     0.157068        0
# 2         0.0      0.076923        0.397993     0.157068        0
# 3         0.6      0.230769        0.230769     0.319372        0
# 4         0.6      0.230769        0.230769     0.319372        0

# %%
model_sc = sm.Logit.from_formula(fm_str, df_sc)

# %%
result2 = model_sc.fit(maxiter=100)
print(result2.summary2())
# Out:
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.002886
#          Iterations: 100
#                                   Results: Logit
# ===================================================================================
# Model:                    Logit                  Pseudo R-squared:       0.624
# Dependent Variable:       FZ_flag                AIC:                    67.8305
# Date:                     2020-02-12 16:26       BIC:                    157.3808
# No. Observations:         7248                   Log-Likelihood:         -20.915
# Df Model:                 12                     LL-Null:                -55.595
# Df Residuals:             7235                   LLR p-value:            4.2214e-10
# Converged:                0.0000                 Scale:                  1.0000
# No. Iterations:           100.0000
# -----------------------------------------------------------------------------------
#               Coef.       Std.Err.       z    P>|z|       [0.025         0.975]
# -----------------------------------------------------------------------------------
# Intercept    -339.5404  14990025.6616 -0.0000 1.0000  -29380249.9645  29379570.8838
# Temp           29.8846        15.2484  1.9599 0.0500         -0.0017        59.7710
# Rain           13.5729        10.0556  1.3498 0.1771         -6.1358        33.2816
# WindSpeed      12.6915         5.5505  2.2866 0.0222          1.8128        23.5702
# Moist           6.9437         5.0814  1.3665 0.1718         -3.0157        16.9031
# hPa          -169.9752        82.5237 -2.0597 0.0394       -331.7188        -8.2317
# DewTemp        94.2088        52.7459  1.7861 0.0741         -9.1711       197.5888
# CurhPa          1.6508         4.5195  0.3653 0.7149         -7.2073        10.5089
# SnowCm      -7827.3976 412396700.5530 -0.0000 1.0000 -808290507.8247 808274853.0294
# Snow3hr         8.9819        15.4157  0.5826 0.5601        -21.2324        39.1962
# Clouds_10     314.5618  14990025.6616  0.0000 1.0000  -29379595.8623  29380224.9860
# MClouds_10      0.3881         1.5227  0.2549 0.7988         -2.5964         3.3726
# SurfaceTemp   -42.5560        21.3592 -1.9924 0.0463        -84.4194        -0.6927
# ===================================================================================
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\base\model.py:512: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
